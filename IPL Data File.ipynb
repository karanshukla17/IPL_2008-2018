# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ball = pd.read_csv(r'...\Ball_by_Ball.csv')
match = pd.read_csv(r'...\Match.csv')
player = pd.read_csv(r'...\Player.csv')
player_match = pd.read_csv(r'...\Player_Match.csv')
season = pd.read_csv(r'...\Season.csv')
team = pd.read_csv(r'...\Team.csv')

# %% [markdown]
# # Minor Info about the data

# %%
print(team['Team_Name'].count(),'are the total number of teams that have partcipated in IPL 2008 - 2016')
# Out:
# 13 are the total number of teams that have partcipated in IPL 2008 - 2016

# %%
print(player['Player_Name'].nunique(),'are the total number of players and umpires that have partcipated in IPL 2008 - 2016')
# Out:
# 523 are the total number of players and umpires that have partcipated in IPL 2008 - 2016

# %%
print(match['Match_Id'].nunique(),'are the number of matches that have been played in IPL 2008 - 2016')
# Out:
# 577 are the number of matches that have been played in IPL 2008 - 2016

# %% [markdown]
# # Number of Matches played in each Season

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Season_Id', data=match)
sns.set_context("talk")
plt.ylabel("Number of Matches",fontsize = 20, weight = 'bold')
plt.xlabel("Season Number",fontsize = 20, weight = 'bold')
plt.title("Number of Matches played in each season",fontsize = 25, weight = 'bold');
plt.show()

# %%
match['Season_Id'].value_counts()
# Out:
# 6    76
# 5    74
# 4    73
# 3    60
# 7    60
# 9    60
# 8    59
# 1    58
# 2    57
# Name: Season_Id, dtype: int64

# %% [markdown]
# # Number of Matches played in each Stadium

# %%
plt.figure(figsize=(12,10))
sns.countplot(y='Venue_Name', data=match)
plt.yticks(rotation='horizontal')
plt.xlabel("Number of Matches",fontsize = 25, weight = 'bold')
plt.ylabel("Stadium Name",fontsize = 25, weight = 'bold')
plt.title("Number of Matches played in each Stadium",fontsize = 30, weight = 'bold');
plt.show()

# %%
match['Venue_Name'].value_counts()
# Out:
# M Chinnaswamy Stadium                                   58
# Eden Gardens                                            54
# Feroz Shah Kotla                                        53
# Wankhede Stadium                                        49
# MA Chidambaram Stadium, Chepauk                         48
# Rajiv Gandhi International Stadium, Uppal               41
# Punjab Cricket Association Stadium, Mohali              35
# Sawai Mansingh Stadium                                  33
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Kingsmead                                               15
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Brabourne Stadium                                       11
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# Himachal Pradesh Cricket Association Stadium             9
# ...

# %%
plt.figure(figsize=(12,10))
sns.set_context("talk")
sns.countplot(y='City_Name', data=match)
plt.xlabel("Number of Matches",fontsize = 25, weight = 'bold')
plt.ylabel("City Name",fontsize = 25, weight = 'bold')
plt.title("Number of Matches played in each City",fontsize = 30, weight = 'bold');
plt.show()

# %%
match['City_Name'].value_counts()
# Out:
# Mumbai            77
# Bangalore         58
# Kolkata           54
# Delhi             53
# Chennai           48
# Chandigarh        42
# Hyderabad         41
# Jaipur            33
# Pune              25
# Abu Dhabi         20
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Dharamsala         9
# Johannesburg       8
# Cuttack            7
# Cape Town          7
# Port Elizabeth     7
# Ranchi             7
# Raipur             6
# Kochi              5
# Rajkot             5
# Kimberley          3
# East London        3
# Nagpur             3
# Bloemfontein       2
# Indore             2
# Kanpur             2
# Name: City_Name, dtype: int64

# %% [markdown]
# # Dismisal count

# %%
dismisal = ball['Dissimal_Type']

# %%
dismisal = dismisal.replace([' '],np.nan)

# %%
dismisal.dropna(axis = 0, inplace = True)

# %%
dismisal_count= dismisal.value_counts()

# %%
plt.style.use('ggplot')
dismisal_count.plot(kind='barh',figsize=(12,6),color='c')
sns.set_context('talk')
plt.xlabel("Number of Dismisals",fontsize = 15, weight = 'bold')
plt.ylabel("Type of Dismisal",fontsize = 15, weight = 'bold')
plt.title("Count of the various Dismisal Types",fontsize = 20, weight = 'bold')
plt.show()

# %%
dismisal.value_counts()
# Out:
# caught                   3245
# bowled                   1028
# run out                   583
# lbw                       326
# stumped                   187
# caught and bowled         148
# retired hurt                8
# hit wicket                  6
# obstructing the field       1
# Name: Dissimal_Type, dtype: int64

# %% [markdown]
# # Cleaning Ball by Ball File

# %%
ball.drop(['Player_dissimal_Id' ,	'Dissimal_Type' ,	'Fielder_Id'],inplace=True,axis=1)

# %%
ball
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0         335987           1        1        1                1
# 1         335987           1        1        2                1
# 2         335987           1        1        3                1
# 3         335987           1        1        4                1
# 4         335987           1        1        5                1
# ...          ...         ...      ...      ...              ...
# 136585    981024           2       20        2                2
# 136586    981024           2       20        3                2
# 136587    981024           2       20        4                2
# 136588    981024           2       20        5                2
# 136589    981024           2       20        6                2
#
#         Team_Bowling_Id  Striker_Id  Striker_Batting_Position  Non_Striker_Id  \
# 0                     2           1                         1               2
# ...

# %%
ball = pd.merge(ball, team, left_on='Team_Batting_Id',right_on='Team_Id',how='left')

# %%
ball.drop(['Team_Id','Team_Name','Team_Batting_Id'],inplace=True,axis=1)

# %%
ball.rename(columns={'Team_Short_Code':'Batting_Team'}, inplace=True)
ball.head()
# Out:
#    Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Bowling_Id  Striker_Id  \
# 0    335987           1        1        1                2           1
# 1    335987           1        1        2                2           2
# 2    335987           1        1        3                2           2
# 3    335987           1        1        4                2           2
# 4    335987           1        1        5                2           2
#
#    Striker_Batting_Position  Non_Striker_Id  Bowler_Id Batsman_Scored  \
# 0                         1               2         14              0
# 1                         2               1         14              0
# 2                         2               1         14              0
# 3                         2               1         14              0
# 4                         2               1         14              0
#
#   Extra_Type Extra_Runs Batting_Team
# 0    legbyes          1          KKR
# 1                                KKR
# ...

# %%
ball = pd.merge(ball, team, left_on='Team_Bowling_Id',right_on='Team_Id',how='left')

# %%
ball.drop(['Team_Id','Team_Name','Team_Bowling_Id'],inplace=True,axis=1)

# %%
ball.rename(columns={'Team_Short_Code':'Bowling_Team'}, inplace=True)
ball.head()
# Out:
#    Match_Id  Innings_Id  Over_Id  Ball_Id  Striker_Id  \
# 0    335987           1        1        1           1
# 1    335987           1        1        2           2
# 2    335987           1        1        3           2
# 3    335987           1        1        4           2
# 4    335987           1        1        5           2
#
#    Striker_Batting_Position  Non_Striker_Id  Bowler_Id Batsman_Scored  \
# 0                         1               2         14              0
# 1                         2               1         14              0
# 2                         2               1         14              0
# 3                         2               1         14              0
# 4                         2               1         14              0
#
#   Extra_Type Extra_Runs Batting_Team Bowling_Team
# 0    legbyes          1          KKR          RCB
# 1                                KKR          RCB
# 2      wides          1          KKR          RCB
# ...

# %%
ball = pd.merge(ball, player, left_on='Striker_Id',right_on='Player_Id',how = 'left')

# %%
ball.drop(['Striker_Id','Player_Id','DOB', 'Batting_Hand', 'Bowling_Skill', 'Country','Is_Umpire',],inplace=True,axis=1)

# %%
ball.rename(columns={'Player_Name':'Striker_Name'}, inplace=True)
ball.head()
# Out:
#    Match_Id  Innings_Id  Over_Id  Ball_Id  Striker_Batting_Position  \
# 0    335987           1        1        1                         1
# 1    335987           1        1        2                         2
# 2    335987           1        1        3                         2
# 3    335987           1        1        4                         2
# 4    335987           1        1        5                         2
#
#    Non_Striker_Id  Bowler_Id Batsman_Scored Extra_Type Extra_Runs  \
# 0               2         14              0    legbyes          1
# 1               1         14              0
# 2               1         14              0      wides          1
# 3               1         14              0
# 4               1         14              0
#
#   Batting_Team Bowling_Team Striker_Name
# 0          KKR          RCB   SC Ganguly
# 1          KKR          RCB  BB McCullum
# 2          KKR          RCB  BB McCullum
# 3          KKR          RCB  BB McCullum
# ...

# %%
ball = pd.merge(ball, player,left_on='Non_Striker_Id',right_on='Player_Id',how='left')

# %%
ball.drop(['Non_Striker_Id','Player_Id','DOB', 'Batting_Hand', 'Bowling_Skill', 'Country','Is_Umpire',],inplace=True,axis=1)

# %%
ball.rename(columns={'Player_Name':'Non_Striker_Name'}, inplace=True)
ball.head()
# Out:
#    Match_Id  Innings_Id  Over_Id  Ball_Id  Striker_Batting_Position  \
# 0    335987           1        1        1                         1
# 1    335987           1        1        2                         2
# 2    335987           1        1        3                         2
# 3    335987           1        1        4                         2
# 4    335987           1        1        5                         2
#
#    Bowler_Id Batsman_Scored Extra_Type Extra_Runs Batting_Team Bowling_Team  \
# 0         14              0    legbyes          1          KKR          RCB
# 1         14              0                                KKR          RCB
# 2         14              0      wides          1          KKR          RCB
# 3         14              0                                KKR          RCB
# 4         14              0                                KKR          RCB
#
#   Striker_Name Non_Striker_Name
# 0   SC Ganguly      BB McCullum
# 1  BB McCullum       SC Ganguly
# ...

# %%
ball= pd.merge(ball, player,left_on='Bowler_Id',right_on='Player_Id',how='left')

# %%
ball.drop(['Bowler_Id','Player_Id','DOB', 'Batting_Hand', 'Bowling_Skill', 'Country','Is_Umpire',],inplace=True,axis=1)

# %% [markdown]
# ### Updated ball to ball

# %%
ball.rename(columns={'Player_Name':'Bowler_Name'}, inplace=True)
ball.head(20)
# Out:
#     Match_Id  Innings_Id  Over_Id  Ball_Id  Striker_Batting_Position  \
# 0     335987           1        1        1                         1
# 1     335987           1        1        2                         2
# 2     335987           1        1        3                         2
# 3     335987           1        1        4                         2
# 4     335987           1        1        5                         2
# 5     335987           1        1        6                         2
# 6     335987           1        1        7                         2
# 7     335987           1        2        1                         2
# 8     335987           1        2        2                         2
# 9     335987           1        2        3                         2
# 10    335987           1        2        4                         2
# 11    335987           1        2        5                         2
# 12    335987           1        2        6                         2
# ...

# %% [markdown]
# # Cleaning Match File

# %%
match.head()
# Out:
#    Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 0    335987  18-Apr-08             2                 1          1
# 1    335988  19-Apr-08             4                 3          1
# 2    335989  19-Apr-08             6                 5          1
# 3    335990  20-Apr-08             7                 2          1
# 4    335991  20-Apr-08             1                 8          1
#
#                                    Venue_Name  Toss_Winner_Id Toss_Decision  \
# 0                       M Chinnaswamy Stadium               2         field
# 1  Punjab Cricket Association Stadium, Mohali               3           bat
# 2                            Feroz Shah Kotla               5           bat
# 3                            Wankhede Stadium               7           bat
# 4                                Eden Gardens               8           bat
#
#    IS_Superover  IS_Result  Is_DuckWorthLewis    Win_Type  Won_By  \
# ...

# %%
match.drop(['First_Umpire_Id',	'Second_Umpire_Id'], axis =1, inplace = True )

# %%
match= pd.merge(match, team, left_on='Team_Name_Id',right_on='Team_Id',how='left')

# %%
match.drop(['Team_Name_Id','Team_Id','Team_Name'], axis =1, inplace=True)

# %%
match.rename(columns={'Team_Short_Code':'Team_Name'}, inplace=True)

# %%
match.head()
# Out:
#    Match_Id Match_Date  Opponent_Team_Id  Season_Id  \
# 0    335987  18-Apr-08                 1          1
# 1    335988  19-Apr-08                 3          1
# 2    335989  19-Apr-08                 5          1
# 3    335990  20-Apr-08                 2          1
# 4    335991  20-Apr-08                 8          1
#
#                                    Venue_Name  Toss_Winner_Id Toss_Decision  \
# 0                       M Chinnaswamy Stadium               2         field
# 1  Punjab Cricket Association Stadium, Mohali               3           bat
# 2                            Feroz Shah Kotla               5           bat
# 3                            Wankhede Stadium               7           bat
# 4                                Eden Gardens               8           bat
#
#    IS_Superover  IS_Result  Is_DuckWorthLewis    Win_Type  Won_By  \
# 0             0          1                  0     by runs   140.0
# ...

# %%
match = pd.merge(match, team, left_on='Opponent_Team_Id',right_on='Team_Id',how ='left')

# %%
match.drop(['Opponent_Team_Id','Team_Id','Team_Name_y'], axis =1, inplace=True)

# %%
match.rename(columns={'Team_Short_Code':'Opponent_Name'}, inplace=True)

# %%
match.head()
# Out:
#    Match_Id Match_Date  Season_Id                                  Venue_Name  \
# 0    335987  18-Apr-08          1                       M Chinnaswamy Stadium
# 1    335988  19-Apr-08          1  Punjab Cricket Association Stadium, Mohali
# 2    335989  19-Apr-08          1                            Feroz Shah Kotla
# 3    335990  20-Apr-08          1                            Wankhede Stadium
# 4    335991  20-Apr-08          1                                Eden Gardens
#
#    Toss_Winner_Id Toss_Decision  IS_Superover  IS_Result  Is_DuckWorthLewis  \
# 0               2         field             0          1                  0
# 1               3           bat             0          1                  0
# 2               5           bat             0          1                  0
# 3               7           bat             0          1                  0
# 4               8           bat             0          1                  0
#
# ...

# %%
match = pd.merge(match, team, left_on='Toss_Winner_Id',right_on='Team_Id',how='left')

# %%
match.drop(['Toss_Winner_Id','Team_Id','Team_Name'], axis =1, inplace=True)

# %%
match.rename(columns={'Team_Short_Code':'Toss_Winner'}, inplace=True)

# %%
match.head()
# Out:
#    Match_Id Match_Date  Season_Id                                  Venue_Name  \
# 0    335987  18-Apr-08          1                       M Chinnaswamy Stadium
# 1    335988  19-Apr-08          1  Punjab Cricket Association Stadium, Mohali
# 2    335989  19-Apr-08          1                            Feroz Shah Kotla
# 3    335990  20-Apr-08          1                            Wankhede Stadium
# 4    335991  20-Apr-08          1                                Eden Gardens
#
#   Toss_Decision  IS_Superover  IS_Result  Is_DuckWorthLewis    Win_Type  \
# 0         field             0          1                  0     by runs
# 1           bat             0          1                  0     by runs
# 2           bat             0          1                  0  by wickets
# 3           bat             0          1                  0  by wickets
# 4           bat             0          1                  0  by wickets
#
# ...

# %%
match = pd.merge(match, team, left_on='Match_Winner_Id',right_on='Team_Id',how='left')

# %%
match.drop(['Match_Winner_Id','Team_Id','Team_Name'], axis =1, inplace=True)

# %%
match.rename(columns={'Team_Short_Code':'Match_Winner'}, inplace=True)

# %%
match.head()
# Out:
#    Match_Id Match_Date  Season_Id                                  Venue_Name  \
# 0    335987  18-Apr-08          1                       M Chinnaswamy Stadium
# 1    335988  19-Apr-08          1  Punjab Cricket Association Stadium, Mohali
# 2    335989  19-Apr-08          1                            Feroz Shah Kotla
# 3    335990  20-Apr-08          1                            Wankhede Stadium
# 4    335991  20-Apr-08          1                                Eden Gardens
#
#   Toss_Decision  IS_Superover  IS_Result  Is_DuckWorthLewis    Win_Type  \
# 0         field             0          1                  0     by runs
# 1           bat             0          1                  0     by runs
# 2           bat             0          1                  0  by wickets
# 3           bat             0          1                  0  by wickets
# 4           bat             0          1                  0  by wickets
#
# ...

# %%
match = pd.merge(match, player, left_on='Man_Of_The_Match_Id',right_on='Player_Id',how='left')

# %%
match.drop(['Man_Of_The_Match_Id','Player_Id','DOB', 'Batting_Hand', 'Bowling_Skill', 'Country','Is_Umpire',],inplace=True,axis=1)

# %%
match.rename(columns={'Player_Name':'Man_Of_The_Match'}, inplace=True)

# %% [markdown]
# ### Updated match

# %%
match.head(10)
# Out:
#    Match_Id Match_Date  Season_Id                                  Venue_Name  \
# 0    335987  18-Apr-08          1                       M Chinnaswamy Stadium
# 1    335988  19-Apr-08          1  Punjab Cricket Association Stadium, Mohali
# 2    335989  19-Apr-08          1                            Feroz Shah Kotla
# 3    335990  20-Apr-08          1                            Wankhede Stadium
# 4    335991  20-Apr-08          1                                Eden Gardens
# 5    335992  21-Apr-08          1                      Sawai Mansingh Stadium
# 6    335993  22-Apr-08          1   Rajiv Gandhi International Stadium, Uppal
# 7    335994  23-Apr-08          1             MA Chidambaram Stadium, Chepauk
# 8    335995  24-Apr-08          1   Rajiv Gandhi International Stadium, Uppal
# 9    335996  25-Apr-08          1  Punjab Cricket Association Stadium, Mohali
#
#   Toss_Decision  IS_Superover  IS_Result  Is_DuckWorthLewis    Win_Type  \
# ...

# %% [markdown]
# # Man of the Match and Highest Team Wins

# %%
print((match['Man_Of_The_Match'].value_counts()).idxmax(),' : has won the most number of MAN OF THE MATCH awards')
print(((match['Match_Winner']).value_counts()).idxmax(),': has the highest number of team wins')
# Out:
# CH Gayle  : has won the most number of MAN OF THE MATCH awards
# MI : has the highest number of team wins

# %%
print(match['Man_Of_The_Match'].nunique(),':are the total number of players who have won atleast 1 Man of the Match Awards')
# Out:
# 187 :are the total number of players who have won atleast 1 Man of the Match Awards

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Match_Winner', data=match)
sns.set_context("talk")
plt.xlabel("Team Names",fontsize = 20, weight = 'bold')
plt.ylabel("Number of Match Wins",fontsize = 20, weight = 'bold')
plt.title("Total Number of Match Wins by Each Team",fontsize = 25, weight = 'bold');
plt.show()

# %%
match['Match_Winner'].value_counts()
# Out:
# MI      80
# CSK     79
# RCB     70
# KKR     68
# RR      63
# KXIP    63
# DD      56
# SRH     34
# DC      29
# PW      12
# GL       9
# KTK      6
# RPS      5
# Name: Match_Winner, dtype: int64

# %%
motm = match['Man_Of_The_Match'].value_counts()

# %%
plt.style.use('seaborn-dark-palette')
motm.head(7).plot(kind='barh',figsize=(12,6))
sns.set_context('talk')
plt.xlabel("Number of Awards",fontsize = 20, weight = 'bold')
plt.ylabel("Player Names",fontsize = 20, weight = 'bold')
plt.title("Top 7 Man of the Matches Award Winners",fontsize = 25, weight = 'bold')
plt.show()

# %%
motm.head(7)
# Out:
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# SK Raina          13
# RG Sharma         13
# MS Dhoni          12
# Name: Man_Of_The_Match, dtype: int64

# %%
data = player['Batting_Hand'].value_counts()
labels = ['Right Handed','Left Handed']
colors = sns.color_palette('Set2')
sns.set_context('talk')
plt.pie(data, labels = labels,colors=colors, autopct='%.0f%%',shadow=True,startangle=180,radius=2)
plt.title('Batting Style',fontsize=20, weight='bold')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Country', data=player)
sns.set_context('talk')
plt.xlabel("Country Names",fontsize=20,weight='bold')
plt.xticks( rotation=45, horizontalalignment='right')
plt.ylabel("Number of Players",fontsize=20,weight='bold')
plt.title("Total Number of Players that played IPL from each country",fontsize=25)
plt.show()

# %%
player['Country'].value_counts()
# Out:
# India           291
# Australia        78
# South Africa     44
# New Zealand      26
# Sri Lanka        22
# West Indies      20
# England          18
# Pakistan         15
# Bangladesh        5
# Zimbabwea         3
# Netherlands       1
# Name: Country, dtype: int64

# %%
ball=ball.replace([' '],[0])
ball=ball.replace(['Do_nothing'],[0])
ball["Batsman_Scored"] = ball["Batsman_Scored"].astype("int64")

# %%
runs=pd.pivot_table(ball, index = "Striker_Name", values ="Batsman_Scored", aggfunc = "sum").sort_values(by =['Batsman_Scored'],ascending = False).head(10)

# %%
plt.style.use('seaborn-dark')
runs.plot(kind='barh',figsize=(12,6))
sns.set_context('talk')
plt.xlabel("Runs Scored",fontsize = 20, weight = 'bold')
plt.ylabel("Player Names",fontsize = 20, weight = 'bold')
plt.title("Top 10 Highest Runs Scorer",fontsize = 25, weight = 'bold')
plt.show()

# %%
runs
# Out:
#                 Batsman_Scored
# Striker_Name
# SK Raina                  4106
# V Kohli                   4105
# RG Sharma                 3874
# G Gambhir                 3634
# CH Gayle                  3447
# RV Uthappa                3390
# DA Warner                 3373
# AB de Villiers            3270
# MS Dhoni                  3270
# S Dhawan                  3082

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Bowling_Skill', data=player)
plt.xticks( rotation=45, horizontalalignment='right')
plt.title("Player's Bowling Style", fontsize=25,weight='bold')
plt.xlabel('Skill Name',fontsize=20,weight='bold')
plt.ylabel('Number of Players',fontsize=20,weight='bold')
plt.show()

# %%
player['Bowling_Skill'].value_counts()
# Out:
# Right-arm medium          104
# Right-arm offbreak         82
# Right-arm fast-medium      53
# Slow left-arm orthodox     44
# Right-arm medium-fast      38
# Legbreak                   24
# Legbreak googly            21
# Right-arm fast             20
# Left-arm fast-medium       13
# Left-arm medium            11
# Left-arm medium-fast        8
# Slow left-arm chinaman      5
# Left-arm fast               3
# Right-arm bowler            1
# Name: Bowling_Skill, dtype: int64

# %%
data = match['Toss_Decision'].value_counts()
labels = ['Field','Bat']
colors = sns.color_palette('bright')
sns.set_context('talk')
plt.pie(data, labels = labels,colors=colors, autopct='%.0f%%',shadow=True,startangle=90,radius=2)
plt.title('Toss Decisions',fontsize=20, weight='bold')
plt.show()

# %% [markdown]
# # Cleaning Player Match File

# %%
cap=pd.merge(left=player_match,right=team,on='Team_Id',how='left')
cap=pd.merge(left=cap,right=player,on='Player_Id',how='left')
cap.head()
# Out:
#    Match_Id  Player_Id  Team_Id  Is_Keeper  Is_Captain              Team_Name  \
# 0    335987          1        1          0           1  Kolkata Knight Riders
# 1    335987          2        1          0           0  Kolkata Knight Riders
# 2    335987          3        1          0           0  Kolkata Knight Riders
# 3    335987          4        1          0           0  Kolkata Knight Riders
# 4    335987          5        1          0           0  Kolkata Knight Riders
#
#   Team_Short_Code      Player_Name        DOB Batting_Hand  \
# 0             KKR       SC Ganguly  08-Jul-72    Left_Hand
# 1             KKR      BB McCullum  27-Sep-81   Right_Hand
# 2             KKR       RT Ponting  19-Dec-74   Right_Hand
# 3             KKR        DJ Hussey  15-Jul-77   Right_Hand
# 4             KKR  Mohammad Hafeez  17-Oct-80   Right_Hand
#
#         Bowling_Skill      Country  Is_Umpire
# 0    Right-arm medium        India          0
# 1    Right-arm medium  New Zealand          0
# ...

# %%
cap.drop(['Match_Id','Team_Id','DOB','Is_Umpire','Batting_Hand','Bowling_Skill','Team_Name'], axis =1, inplace=True)
cap.head()
# Out:
#    Player_Id  Is_Keeper  Is_Captain Team_Short_Code      Player_Name  \
# 0          1          0           1             KKR       SC Ganguly
# 1          2          0           0             KKR      BB McCullum
# 2          3          0           0             KKR       RT Ponting
# 3          4          0           0             KKR        DJ Hussey
# 4          5          0           0             KKR  Mohammad Hafeez
#
#        Country
# 0        India
# 1  New Zealand
# 2    Australia
# 3    Australia
# 4     Pakistan

# %%
index1 = cap[cap['Is_Captain']==0].index
captain1 = cap.drop(index1)
captain1.head()
# Out:
#     Player_Id  Is_Keeper  Is_Captain Team_Short_Code   Player_Name    Country
# 0           1          0           1             KKR    SC Ganguly      India
# 5           6          0           1             RCB      R Dravid      India
# 25         20          1           1             CSK      MS Dhoni      India
# 32         27          0           1            KXIP  Yuvraj Singh      India
# 52         38          0           1              RR      SK Warne  Australia

# %% [markdown]
# ## List of all the captains of each team

# %%
captain1.groupby(['Team_Short_Code','Player_Name']).nunique()
# Out:
#                                   Player_Id  Is_Keeper  Is_Captain  Country
# Team_Short_Code Player_Name
# CSK             MS Dhoni                  1          2           1        1
#                 SK Raina                  1          1           1        1
# DC              AC Gilchrist              1          1           1        1
#                 CL White                  1          1           1        1
#                 KC Sangakkara             1          2           1        1
#                 VVS Laxman                1          1           1        1
# DD              DA Warner                 1          1           1        1
#                 DPMD Jayawardene          1          1           1        1
#                 G Gambhir                 1          1           1        1
#                 JP Duminy                 1          1           1        1
#                 JR Hopes                  1          1           1        1
# ...

# %%
index2=cap[cap['Is_Keeper']==0].index
keeper1 = cap.drop(index2)
keeper1.head()
# Out:
#     Player_Id  Is_Keeper  Is_Captain Team_Short_Code    Player_Name  \
# 10         11          1           0             RCB     MV Boucher
# 17         62          1           0             KKR        WP Saha
# 25         20          1           1             CSK       MS Dhoni
# 31         26          1           0            KXIP  KC Sangakkara
# 50         36          1           0              RR        M Rawat
#
#          Country
# 10  South Africa
# 17         India
# 25         India
# 31     Sri Lanka
# 50         India

# %%
output1 = keeper1.groupby(['Team_Short_Code','Player_Name']).nunique()

# %% [markdown]
# ## List of all the keepers of each team

# %%
output1.head(50)
# Out:
#                                  Player_Id  Is_Keeper  Is_Captain  Country
# Team_Short_Code Player_Name
# CSK             MS Dhoni                 1          1           1        1
#                 PA Patel                 1          1           1        1
# DC              AC Gilchrist             1          1           2        1
#                 KC Sangakkara            1          1           1        1
#                 KH Devdhar               1          1           1        1
#                 PA Patel                 1          1           1        1
# DD              AB de Villiers           1          1           1        1
#                 CM Gautam                1          1           1        1
#                 KD Karthik               1          1           2        1
#                 KM Jadhav                1          1           1        1
#                 NV Ojha                  1          1           1        1
# ...

# %%
output1.tail(30)
# Out:
#                                  Player_Id  Is_Keeper  Is_Captain  Country
# Team_Short_Code Player_Name
# MI              YV Takawale              1          1           1        1
# PW              M Rawat                  1          1           1        1
#                 RV Uthappa               1          1           1        1
#                 TD Paine                 1          1           1        1
# RCB             AB de Villiers           1          1           1        1
#                 DT Patil                 1          1           1        1
#                 KB Arun Karthik          1          1           1        1
#                 KD Karthik               1          1           2        1
#                 KL Rahul                 1          1           1        1
#                 KM Jadhav                1          1           1        1
#                 MV Boucher               1          1           1        1
# ...

# %% [markdown]
# # Cleaning Season file

# %%
season
# Out:
#    Season_Id  Season_Year  Orange_Cap_Id  Purple_Cap_Id  Man_of_the_Series_Id
# 0          1         2008            100            102                    32
# 1          2         2009             18             61                    53
# 2          3         2010            133            131                   133
# 3          4         2011            162            194                   162
# 4          5         2012            162            190                   315
# 5          6         2013             19             71                    32
# 6          7         2014             46            364                   305
# 7          8         2015            187             71                   334
# 8          9         2016              8            299                     8

# %%
season = pd.merge(season,player,left_on='Orange_Cap_Id',right_on='Player_Id',how='left')

# %%
season.drop(['Orange_Cap_Id','Player_Id','DOB', 'Batting_Hand', 'Bowling_Skill', 'Country','Is_Umpire',],inplace=True,axis=1)

# %%
season.rename(columns={'Player_Name':'Orange_Cap_Winner'}, inplace=True)

# %%
season.head()
# Out:
#    Season_Id  Season_Year  Purple_Cap_Id  Man_of_the_Series_Id  \
# 0          1         2008            102                    32
# 1          2         2009             61                    53
# 2          3         2010            131                   133
# 3          4         2011            194                   162
# 4          5         2012            190                   315
#
#   Orange_Cap_Winner
# 0          SE Marsh
# 1         ML Hayden
# 2      SR Tendulkar
# 3          CH Gayle
# 4          CH Gayle

# %%
season = pd.merge(season,player,left_on='Purple_Cap_Id',right_on='Player_Id',how='left')

# %%
season.drop(['Purple_Cap_Id','Player_Id','DOB', 'Batting_Hand', 'Bowling_Skill', 'Country','Is_Umpire',],inplace=True,axis=1)

# %%
season.rename(columns={'Player_Name':'Purple_Cap_Winner'}, inplace=True)

# %%
season.head()
# Out:
#    Season_Id  Season_Year  Man_of_the_Series_Id Orange_Cap_Winner  \
# 0          1         2008                    32          SE Marsh
# 1          2         2009                    53         ML Hayden
# 2          3         2010                   133      SR Tendulkar
# 3          4         2011                   162          CH Gayle
# 4          5         2012                   315          CH Gayle
#
#   Purple_Cap_Winner
# 0     Sohail Tanvir
# 1          RP Singh
# 2           PP Ojha
# 3        SL Malinga
# 4          M Morkel

# %%
season = pd.merge(season,player,left_on='Man_of_the_Series_Id',right_on='Player_Id',how='left')

# %%
season.drop(['Man_of_the_Series_Id','Player_Id','DOB', 'Batting_Hand', 'Bowling_Skill', 'Country','Is_Umpire',],inplace=True,axis=1)

# %%
season.rename(columns={'Player_Name':'Man_of_the_Series'}, inplace=True)

# %% [markdown]
# # List of all Orange cap, Purple Cap and Man of the Series Winners

# %%
season
# Out:
#    Season_Id  Season_Year Orange_Cap_Winner Purple_Cap_Winner  \
# 0          1         2008          SE Marsh     Sohail Tanvir
# 1          2         2009         ML Hayden          RP Singh
# 2          3         2010      SR Tendulkar           PP Ojha
# 3          4         2011          CH Gayle        SL Malinga
# 4          5         2012          CH Gayle          M Morkel
# 5          6         2013        MEK Hussey          DJ Bravo
# 6          7         2014        RV Uthappa         MM Sharma
# 7          8         2015         DA Warner          DJ Bravo
# 8          9         2016           V Kohli           B Kumar
#
#   Man_of_the_Series
# 0         SR Watson
# 1      AC Gilchrist
# 2      SR Tendulkar
# 3          CH Gayle
# 4         SP Narine
# 5         SR Watson
# 6        GJ Maxwell
# 7        AD Russell
# 8           V Kohli
